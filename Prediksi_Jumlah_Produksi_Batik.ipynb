# %%
import pandas as pd
pd.set_option('display.max_colwidth', None)
data = pd.read_excel('https://github.com/ifan007/Prediksi-Jumlah-Produksi-Batik/blob/main/just%20data%20batik%20campuran.xlsx?raw=true')
data
# Out:
#      Minggu ke-  Kain/m  Malan/balok  Pewarna/sachet  Harga Jual/Rp  \
# 0             1      41           13              37      3075000.0
# 1             2      35           12              36      3500000.0
# 2             3      42           14              42      3990000.0
# 3             4      35           11              30      3500000.0
# 4             5      43           14              44      4300000.0
# ..          ...     ...          ...             ...            ...
# 307         308      32           11              39      3200000.0
# 308         309      30           10              41      2550000.0
# 309         310      44           14              45      3520000.0
# 310         311      31           10              35      3100000.0
# 311         312      43           14              49      3655000.0
#
#      Target-Jumlah Produksi  Unnamed: 6  \
# 0                      41.0         NaN
# 1                      39.0         NaN
# ...

# %%
data = data[['Kain/m','Malan/balok','Pewarna/sachet','Harga Jual/Rp', 'Target-Jumlah Produksi']]
data
# Out:
#      Kain/m  Malan/balok  Pewarna/sachet  Harga Jual/Rp  \
# 0        41           13              37      3075000.0
# 1        35           12              36      3500000.0
# 2        42           14              42      3990000.0
# 3        35           11              30      3500000.0
# 4        43           14              44      4300000.0
# ..      ...          ...             ...            ...
# 307      32           11              39      3200000.0
# 308      30           10              41      2550000.0
# 309      44           14              45      3520000.0
# 310      31           10              35      3100000.0
# 311      43           14              49      3655000.0
#
#      Target-Jumlah Produksi
# 0                      41.0
# 1                      39.0
# 2                      33.0
# 3                      40.0
# 4                      45.0
# ..                      ...
# 307                    40.0
# 308                    42.0
# ...

# %%
data.describe()
# Out:
#            Kain/m  Malan/balok  Pewarna/sachet  Harga Jual/Rp  \
# count  312.000000   312.000000      312.000000   3.070000e+02
# mean    37.685897    12.423077       39.429487   3.507932e+06
# std      4.669535     1.513236        5.667204   4.537367e+05
# min     30.000000    10.000000       30.000000   2.400000e+06
# 25%     33.750000    11.000000       35.000000   3.200000e+06
# 50%     37.000000    12.000000       39.000000   3.500000e+06
# 75%     42.000000    14.000000       44.000000   3.812500e+06
# max     45.000000    15.000000       50.000000   4.500000e+06
#
#        Target-Jumlah Produksi
# count              307.000000
# mean                37.547231
# std                  4.714761
# min                 30.000000
# 25%                 33.000000
# 50%                 38.000000
# 75%                 42.000000
# max                 45.000000

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

plt.figure(figsize=(20,15))
sns.heatmap(data.corr(), annot=True)
plt.title("Heatmap", fontsize = 25);
plt.show()

# %%
data.isnull().sum()
# Out:
# Kain/m                    0
# Malan/balok               0
# Pewarna/sachet            0
# Harga Jual/Rp             5
# Target-Jumlah Produksi    5
# dtype: int64

# %%
data.isnull()
# Out:
#      Kain/m  Malan/balok  Pewarna/sachet  Harga Jual/Rp  \
# 0     False        False           False          False
# 1     False        False           False          False
# 2     False        False           False          False
# 3     False        False           False          False
# 4     False        False           False          False
# ..      ...          ...             ...            ...
# 307   False        False           False          False
# 308   False        False           False          False
# 309   False        False           False          False
# 310   False        False           False          False
# 311   False        False           False          False
#
#      Target-Jumlah Produksi
# 0                     False
# 1                     False
# 2                     False
# 3                     False
# 4                     False
# ..                      ...
# 307                   False
# 308                   False
# ...

# %%
data['Harga Jual/Rp'].fillna(data['Harga Jual/Rp'].mean(), inplace = True)
data['Target-Jumlah Produksi'].fillna(data['Target-Jumlah Produksi'].mean(), inplace = True)
# Out:
# <ipython-input-56-add0dd1aed5b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Harga Jual/Rp'].fillna(data['Harga Jual/Rp'].mean(), inplace = True)
# <ipython-input-56-add0dd1aed5b>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Target-Jumlah Produksi'].fillna(data['Target-Jumlah Produksi'].mean(), inplace = True)

# %%
data.isnull().sum()
# Out:
# Kain/m                    0
# Malan/balok               0
# Pewarna/sachet            0
# Harga Jual/Rp             0
# Target-Jumlah Produksi    0
# dtype: int64

# %%
x = data.iloc[:,:4].values
y = data.iloc[:,-1].values

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
scaler.fit(data)
x = scaler.fit_transform(x)
y = scaler.fit_transform(y.reshape(-1, 1))

# %%
x
# Out:
# array([[0.73333333, 0.6       , 0.35      , 0.32142857],
#        [0.33333333, 0.4       , 0.3       , 0.52380952],
#        [0.8       , 0.8       , 0.6       , 0.75714286],
#        ...,
#        [0.93333333, 0.8       , 0.75      , 0.53333333],
#        [0.06666667, 0.        , 0.25      , 0.33333333],
#        [0.86666667, 0.8       , 0.95      , 0.59761905]])

# %%
y
# Out:
# array([[0.73333333],
#        [0.6       ],
#        [0.2       ],
#        [0.66666667],
#        [1.        ],
#        [0.06666667],
#        [0.86666667],
#        [0.33333333],
#        [0.13333333],
#        [0.86666667],
#        [0.4       ],
#        [0.73333333],
#        [0.53333333],
#        [0.2       ],
#        [0.33333333],
#        [0.4       ],
#        [0.26666667],
#        [0.        ],
#        [1.        ],
#        [1.        ],
#        [0.86666667],
#        [0.50314875],
#        [1.        ],
#        [0.06666667],
#        [0.33333333],
#        [0.06666667],
#        [0.        ],
#        [0.2       ],
#        [1.        ],
#        [0.06666667],
#        [0.66666667],
#        [0.13333333],
#        [0.8       ],
#        [0.6       ],
#        [0.06666667],
#        [0.86666667],
#        [0.2       ],
#        [1.        ],
#        [0.33333333],
#        [0.26666667],
#        [0.73333333],
#        [0.6       ],
#        [0.46666667],
# ...

# %%
x.shape
# Out:
# (312, 4)

# %%
y.shape
# Out:
# (312, 1)

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# Create the neural network model
model = Sequential()
model.add(Dense(128, activation='relu', input_shape=(4,)))
model.add(Dense(64, activation='relu'))
model.add(Dense(1))

# %%
from sklearn.metrics import mean_squared_error
# Compile the model
model.compile(optimizer='adam', loss='mean_squared_error')

# %%
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 128)               640
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dense_2 (Dense)             (None, 1)                 65
#
# ...
# Total params: 8961 (35.00 KB)
# Trainable params: 8961 (35.00 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None

# %%
# Train the model
history = model.fit(x_train, y_train, epochs=100, batch_size=5, verbose=1)
# Out:
# Epoch 1/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0904
# Epoch 2/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0909
# Epoch 3/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0905
# Epoch 4/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0927
# Epoch 5/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0894
# Epoch 6/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0908
# Epoch 7/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0899
# Epoch 8/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0901
# Epoch 9/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0868
# Epoch 10/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0884
# Epoch 11/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0887
# Epoch 12/100
# ...

# %%
# Evaluate the model
train_loss = model.evaluate(x_train, y_train, verbose=0)
test_loss = model.evaluate(x_test, y_test, verbose=0)
print("Train Loss:", train_loss)
print("Test Loss:", test_loss)
# Out:
# Train Loss: 0.07293447852134705
# Test Loss: 0.11903097480535507

# %%
# Make predictions
y_train_pred = model.predict(x_train)
y_test_pred = model.predict(x_test)
# Out:
# ...
# 2/2 [==============================] - 0s 12ms/step

# %%
# Inverse transform the scaled predictions
y_train_pred = scaler.inverse_transform(y_train_pred)
y_test_pred = scaler.inverse_transform(y_test_pred)
y_train = scaler.inverse_transform(y_train)
y_test = scaler.inverse_transform(y_test)

# %%
# Calculate root mean squared error
import numpy as np
train_rmse = np.sqrt(mean_squared_error(y_train, y_train_pred))
test_rmse = np.sqrt(mean_squared_error(y_test, y_test_pred))
print("Train RMSE:", train_rmse)
print("Test RMSE:", test_rmse)
# Out:
# Train RMSE: 4.050957388880231
# Test RMSE: 5.175129659464249

# %%
# Visualize the results
plt.figure(figsize=(15, 10))
plt.plot(y_train, color='b', label='Actual')
plt.plot(y_train_pred, color='r', label='Predicted')
plt.title("Train Set - Actual vs Predicted")
plt.ylim(ymin=0,ymax=50)
plt.legend()
plt.show()

# %%
# Visualize the results
plt.figure(figsize=(15, 10))
plt.plot(y_test, color='b', label='Actual')
plt.plot(y_test_pred, color='r', label='Predicted')
plt.title("Test Set - Actual vs Predicted")
plt.legend()
plt.show()
